# %%
import os
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

rawData = "../data/raw/dataset.csv"
processedData = "../data/processed"
outPath = os.path.join(processedData, "dataset_full_preprocessed.csv")


df = pd.read_csv(rawData)
df.shape
# Out:
# (13910, 131)

# %%
numeric_df = df.select_dtypes(include=[np.number])
print("Numerical features shape:", numeric_df.shape)

imputer = SimpleImputer(strategy="median")
imputed_data = imputer.fit_transform(numeric_df)

scaler = StandardScaler()
scaled_data = scaler.fit_transform(imputed_data)
# Out:
# Numerical features shape: (13910, 131)

# %%
processed_df = pd.DataFrame(
    scaled_data,
    columns=numeric_df.columns
)
    
processed_df.to_csv(outPath, index=False)
