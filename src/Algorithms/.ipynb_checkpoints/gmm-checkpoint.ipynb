# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.decomposition import PCA

datasets = {
    "full": "../../data/processed/ProcessedData.csv",
    "pca": "../../data/reduced/dataPCA.csv",
    "fs": "../../data/reduced/dataFS.csv"
}

outDir = "../../results/gmm"

# %%
def plotGMM(df, labels, datasetName):

    pca2d = PCA(n_components=2, random_state=42)
    X2d = pca2d.fit_transform(df)

    plt.figure(figsize=(6, 5))
    plt.scatter(
        X2d[:, 0],
        X2d[:, 1],
        c=labels,
        cmap="tab10",
        s=5
    )
    plt.title(f"GMM ({datasetName})")
    plt.tight_layout()
    plt.savefig(f"{outDir}/gmm_{datasetName}.png", dpi=200)
    plt.close()

# %%
def runGMM(datasetName, df):

    gmm = GaussianMixture(
        n_components=4,
        covariance_type="full",
        random_state=42
    )

    labels = gmm.fit_predict(df)

    sil = silhouette_score(df, labels)
    db  = davies_bouldin_score(df, labels)

    resultData = df.copy()
    resultData["cluster"] = labels
    resultData.to_csv(
        f"{outDir}/gmm_{datasetName}_clusters.csv",
        index=False
    )

    plotGMM(df, labels, datasetName)

    return {
        "Dataset": datasetName,
        "Algorithm": "GMM",
        "Components": 4,
        "Covariance": "full",
        "Silhouette": sil,
        "Davies_Bouldin": db
    }

# %%
results = []

for name, path in datasets.items():
    df = pd.read_csv(path)
    summary = runGMM(name, df)
    results.append(summary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 for name, path in datasets.items():
#       4     df = pd.read_csv(path)
# ----> 5     summary = runGMM(name, df)
#       6     results.append(summary)
#
# Cell In[3], line 26, in runGMM(datasetName, df)
#      16 resultData.to_csv(
#      17     f"{outDir}/gmm_{datasetName}_clusters.csv",
#      18     index=False
#      19 )
#      21 plotGMM(df, labels, datasetName)
#      23 return {
#      24     "Dataset": datasetName,
#      25     "Algorithm": "GMM",
# ---> 26     "Components": n_components,
#      27     "Covariance": cov_type,
#      28     "Silhouette": sil,
#      29     "Davies_Bouldin": db
#      30 }
#
# NameError: name 'n_components' is not defined

# %%
summaryData = pd.DataFrame(results)
summaryData.to_csv(f"{outDir}/gmm_summary.csv", index=False)
print(summaryData)
