# %%
# Ucitavanje podataka
import os
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler

rawData = "../../data/raw/dataset.csv"
processedDir = "../../data/processed"
outPath = os.path.join(processedDir, "ProcessedData.csv")

df = pd.read_csv(rawData)
df.shape
# Out:
# (13910, 131)

# %%
# Inicijalno sredjivanje (Izbacivanje neNumerickih kolona i bespotrebnih kolona)
df = df.drop(columns=["id"])

y = df["Class"]
X = df.drop(columns=["Class"])

X = X.select_dtypes(include=[np.number])
X.shape
# Out:
# (13910, 129)

# %%
# NaN analiza
nan = X.isna().sum().sum()
nan
# Out:
# np.int64(0)

# %%
# Rad sa outlierima
LQ = 0.01
RQ = 0.99

clippedX = X.copy()

for col in clippedX.columns:
    leftQ = clippedX[col].quantile(LQ)
    rightQ = clippedX[col].quantile(RQ)
    clippedX[col] = clippedX[col].clip(leftQ, rightQ)

# %%
# Standardizacija
scaler = RobustScaler(quantile_range=(5, 95))
scaledX = scaler.fit_transform(clippedX)

# %%
# Cuvanje pretprocesiranog skupa
processedData = pd.DataFrame(
    scaledX,
    columns=X.columns
)

if y is not None:
    processedData["Class"] = y.values

processedData.to_csv(outPath, index=False)
processedData.shape
# Out:
# (13910, 130)
