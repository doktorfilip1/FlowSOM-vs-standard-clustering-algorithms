# %%
# Ucitavanje podataka i inicijalno sredjivanje
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

processedData = "../../data/processed/ProcessedData.csv"
reducedDataDir = "../../data/reduced"
outPath = os.path.join(reducedDataDir, "dataPCA.csv")

df = pd.read_csv(processedData)
df.shape

y = df["Class"]
X = df.drop(columns=["Class"])
X = X.drop(columns=["V129"])
X.shape
# Out:
# (13910, 128)

# %%
# PCA bez ogranicenja komponenti
pcaFull = PCA(random_state=42)
pcaFull.fit(X)
# Out:
# PCA(random_state=42)

# %%
# Explained Variance
explained = pcaFull.explained_variance_ratio_
cumExplained = np.cumsum(explained)

# %%
nComp = np.argmax(cumExplained >= 0.95) + 1

pca = PCA(n_components=nComp, random_state=42)
pcaX = pca.fit_transform(X)

# %%
# Kreiranje i eksport PCA redukovanog dataseta
pcaCol = [f"PC{i+1}" for i in range(nComp)]
pcaData = pd.DataFrame(pcaX, columns=pcaCol)

pcaData.to_csv(outPath, index=False)
pcaData.shape
# Out:
# (13910, 8)

# %%
###########################################################

# %%
# Za seminarski
plt.figure(figsize=(8,5))
plt.plot(cumExplained, marker="o")
plt.axhline(0.95, color="red", linestyle="--")
plt.xlabel("Broj komponenti")
plt.ylabel("Cum EV")
plt.title("PCA EV")
plt.grid()
plt.tight_layout()
plt.savefig(os.path.join(reducedDataDir, "pcaEV.png"), dpi=200)
plt.close()
